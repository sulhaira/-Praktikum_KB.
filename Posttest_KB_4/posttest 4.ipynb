# %% [markdown]
# # Sulhairah(2009106026)
# # Posttest 4

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Life Expectancy Data.csv")
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2944 non-null   object
#  1   Year                             2944 non-null   int64
#  2   Status                           2944 non-null   object
#  3   Life expectancy                  2934 non-null   float64
#  4   Adult Mortality                  2934 non-null   float64
#  5   infant deaths                    2944 non-null   int64
#  6   Alcohol                          2750 non-null   float64
#  7   percentage expenditure           2944 non-null   float64
#  8   Hepatitis B                      2391 non-null   float64
#  9   Measles                          2944 non-null   int64
#  10   BMI                             2910 non-null   float64
#  11  under-five deaths                2944 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# # Bagi dataset menjadi training set dan testing set dengan proporsi 70:30

# %%
# Subset feature dan target
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
print("x_train:", x_train.shape)
print("x_test:", x_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# x_train: (2060, 21)
# x_test: (884, 21)
# y_train: (2060,)
# y_test: (884,)

# %% [markdown]
# # normalisasi data pada salah satu attribute menggunakan Min Max scaler (buatlah copy dataset terlebih dahulu)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()
df_copy = df.filter(
  [
  'Hepatitis B', 
  'Measles', 
  'under-five deaths', 
  'Polio', 
  'Total expenditure' 
  ]
)

# %%
scaled_data = minmax.fit_transform(df_copy)
scaled_data
# Out:
# array([[0.65306122, 0.03125   , 0.4521184 ],
#        [0.62244898, 0.57291667, 0.45327916],
#        [0.64285714, 0.61458333, 0.45037725],
#        ...,
#        [0.73469388, 0.72916667, 0.35751596],
#        [0.76530612, 0.76041667, 0.33604179],
#        [0.79591837, 0.78125   , 0.39059779]])

# %% [markdown]
# # standarisasi pada dataset (buatlah copy dataset terlebih dahulu)

# %%
np.std(df)
# Out:
# C:\Users\Windows10\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3571: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Year                               4.614469e+00
# Life expectancy                    9.521355e+00
# Adult Mortality                    1.242372e+02
# infant deaths                      1.177984e+02
# Alcohol                            4.052921e+00
# percentage expenditure             1.985783e+03
# Hepatitis B                        2.504566e+01
# Measles                            1.145378e+04
#  BMI                               2.004140e+01
# under-five deaths                  1.602706e+02
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
stand = StandardScaler()

# %%
df_copy = df.filter(
[ 'Hepatitis B', 
  'Measles', 
  'under-five deaths', 
  'Polio', 
  'Total expenditure']
    )

# %%
scaled_data= stand.fit_transform(df_copy)
scaled_data
# Out:
# array([[-0.63489228, -3.26118616,  0.88740509],
#        [-0.75467351, -1.04421916,  0.89541235],
#        [-0.67481936, -0.87368323,  0.8753942 ],
#        ...,
#        [-0.31547567, -0.40470944,  0.23481336],
#        [-0.19569444, -0.2768075 ,  0.08667904],
#        [-0.07591321, -0.19153954,  0.46302028]])

# %% [markdown]
# # Data cleaning pada data dengan nilai null (jika tidak ada nilai null pada dataset, maka buatlah menjadi ada). Ganti nilai null sesuai ketentuan. (bilangan bulat : median/modus, bilangan desimal : mean, tulisan : modus)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')

# %%
df["GDP"] = imputer.fit_transform(df[['GDP']])
df["Adult Mortality"] = imputer.fit_transform(df[['Adult Mortality']])
df["Alcohol"] = imputer.fit_transform(df[['Alcohol']])

# %%
#lihat data yang sudah dihilangkan nullnya
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                  0
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df["Hepatitis B"] = imputer.fit_transform(df[['Hepatitis B']])
df["Population"] = imputer.fit_transform(df[['Population']])
df["Total expenditure"] = imputer.fit_transform(df[['Total expenditure']])

# %%
#lihat data yang sudah dihilangkan nullnya
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                          0
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                    0
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                  0
# Population                           0
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df["Income composition of resources"] = imputer.fit_transform(df[['Income composition of resources']])

# %%
#lihat data yang sudah dihilangkan nullnya
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                          0
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                    0
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                  0
# Population                           0
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources      0
# Schooling                          163
# dtype: int64

# %% [markdown]
# # Data cleaning pada data dengan nilai duplikat

# %%
df[df.duplicated()].sum()
# Out:
# Country                            AfghanistanAfghanistanAfghanistanAfghanistanAf...
# Year                                                                           12075
# Status                             DevelopingDevelopingDevelopingDevelopingDevelo...
# Life expectancy                                                                362.3
# Adult Mortality                                                               1628.0
# infant deaths                                                                    406
# Alcohol                                                                         0.06
# percentage expenditure                                                    382.983139
# Hepatitis B                                                                    392.0
# Measles                                                                         9865
#  BMI                                                                           107.3
# ...

# %%
df[df.duplicated()]
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 6   Afghanistan  2015  Developing              65.0            263.0
# 7   Afghanistan  2014  Developing              59.9            271.0
# 8   Afghanistan  2013  Developing              59.9            268.0
# 9   Afghanistan  2012  Developing              59.5            272.0
# 10  Afghanistan  2011  Developing              59.2            275.0
# 11  Afghanistan  2010  Developing              58.8            279.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 6              62     0.01               71.279624         65.0      1154
# 7              64     0.01               73.523582         62.0       492
# 8              66     0.01               73.219243         64.0       430
# 9              69     0.01               78.184215         67.0      2787
# 10             71     0.01                7.097109         68.0      3013
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Ganti tipe data salah satu attribute angka

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
en = OrdinalEncoder()
df["infantdeaths_encoder"] = en.fit_transform(df[["infant deaths"]])
df.head(5)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# #  one hot encoding pada dataset yang kalian miliki

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(sparse = False)

# %%
Status = ohe.fit_transform(df[["Status"]])

# %%
data = pd.DataFrame(Status)
df = df.join(data)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# ...
