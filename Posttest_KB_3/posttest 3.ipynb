# %% [markdown]
# # Sulhairah (2009106026)
# # Posttest 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# # Grafik Pie Chart

# %%
data_pie = df['Status'].value_counts().rename_axis('status').reset_index(name='Id_count')
plt.figure(figsize=(10, 12))
colors = sns.color_palette('Set2', 8)
plt.pie(data_pie.Id_count, labels=data_pie.status, colors=colors, startangle=90, autopct='%.1f%%')
plt.title('status')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# dari grafik pie di atas sudah jelas bahwa  Developing lebih banyak dari Developed dengan presentasi Developing 82.6% sedangkan Developed 17.4%

# %% [markdown]
# # Grafik Batang

# %%
df_10 = df

fig = plt.figure(figsize = (15,8))
ax = fig.add_axes([0,0,1,1])
plt.title("Peminum Alcohol dari tahun ke tahun")
ax.set_xlabel("Year")
ax.set_ylabel("Alcohol")
ax.bar(df_10["Year"],df_10["Alcohol"], color = 'purple')
plt.show()

# %% [markdown]
# jumlah yang mengomsumsi alkohol dari tahub 2000-2003 jumlahnya hampir sama yaitu sekitar 13.0 hingga 14.0, dan terus mengalami peningkatan dari tahun 2004-2007 dan peminum alkohol terbanyak di tahun 2007 yaitu sekitar 17.5. kemudian 2008-2014 terus mengalami kenaikan dan penurunan secara berkala dan pada tahun 2015 mengalami penurunan yang sangat banyak hingga mencapai 10.0

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# # Grafik Garis

# %%
plt.plot(df.Year[0:5], df.Polio[0:5])
plt.title ("Polio")
# Out:
# Text(0.5, 1.0, 'Polio')

# %% [markdown]
# pada tahun 2011 adalah data tertinggi penderita polio dan terus mengalami penurunan yang signifikan dari tahun ke tahun. pada tahun 2015 jumlah terdampak polio menurun secara drastis hingga ke titik terendah

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# # Grafik Boxplot

# %%
sns.boxplot(x='Status',data=df,y='Year', palette='Set2')
plt.title('Status dari tahun ke tahun')
plt.ylabel('Year')
plt.xlabel('Status')
# Out:
# Text(0.5, 0, 'Status')

# %% [markdown]
# antara developing dan developed semuanya seimbang dari tahun 2004-2011. sedangkan pada tahun 2012 developing lebih unggul dari developed
