# %% [markdown]
# # Sulhairah (2009106026)
# # Posttest 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# # Grafik Pie Chart

# %%
data_pie = df['Status'].value_counts().rename_axis('status').reset_index(name='Id_count')
plt.figure(figsize=(10, 12))
colors = sns.color_palette('Set2', 8)
plt.pie(data_pie.Id_count, labels=data_pie.status, colors=colors, startangle=90, autopct='%.1f%%')
plt.title('status')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# dari grafik pie di atas sudah jelas bahwa  Developing lebih banyak dari Developed dengan presentasi Developing 82.6% sedangkan Developed 17.4%

# %%
data_pie.to_csv("Status.csv")

# %% [markdown]
# # Grafik Batang

# %%
data = df_10
fig = plt.figure(figsize = (15,8))
ax = fig.add_axes([0,0,1,1])
plt.title("Peminum Alcohol dari tahun ke tahun")
ax.set_xlabel("Status")
ax.set_ylabel("Polio")
ax.bar(df_10["Status"],df_10["Polio"], color = 'purple')
plt.show(10)

# %% [markdown]
# darigrafik di atas jumlah status developing dan developed yang mengalami polio datanya hampir sama

# %%
data.to_csv("PeminumAlkohol.csv")

# %%
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# # Mengubah Tipe Data Jadi Datetime

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
df["Year"] = pd.to_datetime(data['Year'])

# %%
df.dtypes
# Out:
# Country                                    object
# Year                               datetime64[ns]
# Status                                     object
# Life expectancy                           float64
# Adult Mortality                           float64
# infant deaths                               int64
# Alcohol                                   float64
# percentage expenditure                    float64
# Hepatitis B                               float64
# Measles                                     int64
#  BMI                                      float64
# under-five deaths                           int64
# Polio                                     float64
# Total expenditure                         float64
# Diphtheria                                float64
#  HIV/AIDS                                 float64
# GDP                                       float64
# Population                                float64
#  thinness  1-19 years                     float64
# ...

# %%
alba.resample('M')

# %%
iraq = data[data['Country']== 'Iraq'][['Year','infant deaths','Hepatitis B','Polio']]
iraq.set_index('Year',inplace = True)
iraq.tail()
# Out:
#                                infant deaths  Hepatitis B  Polio
# Year
# 1970-01-01 00:00:00.000002004             30         62.0   69.0
# 1970-01-01 00:00:00.000002003             30         63.0   73.0
# 1970-01-01 00:00:00.000002002             30         65.0   76.0
# 1970-01-01 00:00:00.000002001             30         66.0    8.0
# 1970-01-01 00:00:00.000002000             30         67.0   83.0

# %% [markdown]
# # Grafik Garis

# %%
plt.figure(figsize=(15,10))
plt.plot(iraq.index, alba)
plt.legend(['infant deaths', 'Hepatitis B','Polio']) 
plt.title("Data infant deaths(Kematian Bayi), Hepatitis B, dan Polio di Albania")
plt.xlabel('Year')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# polio pada tahun 1970 di Iraq mengalami penurunan dan kenaikan secara berkala,  masih di tahuh yang sama Hepatits B di iraq hampir rata 60-70 orang dan kematian bayi pada tahuh itu rata di sekitaran 30.

# %%
data.to_csv("datetime.csv")

# %% [markdown]
# # Grafik Boxplot

# %%
sns.boxplot(x='Schooling',data=df,y='Status', palette='Set2')
plt.title('Status dari tahun ke tahun')
plt.ylabel('Status')
plt.xlabel('Schooling')
# Out:
# Text(0.5, 0, 'Schooling')

# %% [markdown]
# dari grafik di atas dapat simpulkan bahwa Status developed lebih banyak Schooling dari Developing
